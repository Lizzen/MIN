# %% [markdown]
# <div id="navegacion" prev="../Ejercicios_Tema_6/uso_numpy.html" next=""></div>
#
# <div class="section-title">Sección 3.7</div>

# %% [markdown]
# # Ejercicios

# %% [markdown]
# Los enlaces que te encuentres en esta página, solo funcionan desde el formato html, no desde el notebook una vez descargado.

# %% [markdown]
# ## Ejercicio 1

# %% [markdown]
# El fichero [rotterdam_rainfall.txt](./datos/rotterdam_rainfall.txt) recoge los datos de las precipitaciones diarias de la estación meteorológica de Rotterdam en 2012.
#
# * La primera columna representa la fecha.
# * La segunda columna representa la cantidad de precipitaciones expresado en 0.1 mm (-1 si es menor a 0.05 mm).
# * El separador de campos es el caracter `, `.
#
# __a)__ Crear un array de `numpy` con los datos del fichero [rotterdam_rainfall.txt](./datos/rotterdam_rainfall.txt). El array ha de llamarse `precipitaciones`.
#
#    * Descarga el fichero  en tu directorio de trabajo.
#    * Carga el fichero mediante la función `loadtxt`. Usa el parámetro  `delimiter` con valor `,`. Usa el parámetro `dtype` para indicar que los valores sean de tipo `int`.

# %%
# Sol
import numpy as np
precipitaciones = np.loadtxt('/content/rotterdam_rainfall.txt', delimiter=',', dtype=int)
precipitaciones
# Out:
# array([[20120101,      207],
#        [20120102,       -1],
#        [20120103,      144],
#        [20120104,       36],
#        [20120105,       84],
#        [20120106,        8],
#        [20120107,       30],
#        [20120108,       -1],
#        [20120109,        8],
#        [20120110,        0],
#        [20120111,       10],
#        [20120112,        9],
#        [20120113,        4],
#        [20120114,       -1],
#        [20120115,        0],
#        [20120116,        0],
#        [20120117,        0],
#        [20120118,       32],
#        [20120119,      144],
#        [20120120,       -1],
#        [20120121,       35],
#        [20120122,       19],
#        [20120123,       16],
#        [20120124,        5],
#        [20120125,        5],
#        [20120126,       33],
#        [20120127,       -1],
#        [20120128,       -1],
#        [20120129,        0],
#        [20120130,        1],
#        [20120131,       -1],
#        [20120201,        0],
#        [20120202,        0],
#        [20120203,       27],
#        [20120204,        0],
#        [20120205,        0],
#        [20120206,        0],
#        [20120207,        0],
#        [20120208,        0],
#        [20120209,       -1],
#        [20120210,        0],
#        [20120211,        0],
#        [20120212,        5],
#        [20120213,       18],
#        [20120214,       19],
#        [20120215,       29],
#        [20120216,        6],
#        [20120217,        4],
#        [20120218,       80],
#        [20120219,       25],
#        [20120220,       -1],
#        [20120221,        0],
#        [20120222,       26],
#        [20120223,       -1],
#        [20120224,        1],
#        [20120225,        0],
#        [20120226,        0],
#        [20120227,        0],
#        [20120228,        3],
#        [20120229,       -1],
#        [20120301,        0],
#        [20120302,        0],
#        [20120303,       -1],
#        [20120304,       43],
#        [20120305,       45],
#        [20120306,        0],
#        [20120307,      123],
#        [20120308,        0],
#        [20120309,        0],
#        [20120310,        1],
#        [20120311,        0],
#        [20120312,        0],
#        [20120313,        0],
#        [20120314,        0],
#        [20120315,        0],
#        [20120316,        0],
#        [20120317,       -1],
#        [20120318,        7],
#        [20120319,        0],
#        [20121213,       -1],
#        [20121214,      103],
#        [20121215,        8],
#        [20121216,       24],
#        [20121217,       31],
#        [20121218,       16],
#        [20121219,        0],
#        [20121220,       68],
#        [20121221,        9],
#        [20121222,      224],
#        [20121223,       76],
#        [20121224,       32],
#        [20121225,      125],
#        [20121226,       45],
#        [20121227,       27],
#        [20121228,       18],
#        [20121229,        2],
#        [20121230,       23],
#        [20121231,       50]])

# %% [markdown]
# __b)__ Averigua el número de días donde la cantidad de precipitaciones es mayor a 0.05 mm (valor mayor que -1).
#
# * Primero crea un filtro donde la cantidad de precipitaciones (columna 1) sea mayor que  -1.
# * Aplica el filtro al array `precipitaciones`. Guarda el resultado en un nuevo array llamado `precip_positivas`.
# * Puedes usar la función `len` para calcular el tamaño del array  `precip_positivas`.

# %%
# Sol: 324 días
precip_positivas = precipitaciones[precipitaciones[:,1] > -1]   #Forma de coger la segunda col
len(precip_positivas)
# Out:
# 324

# %% [markdown]
# __c)__ Calcula el valor medio de la cantidad de precipitación. No tengas en cuenta las precipitaciones con valor -1, por tanto usa el array `precip_positivas` para calcular dicho valor medio.
#
#    * Utiliza la función `mean`.

# %%
# Sol: 30.700617283950617
precip_positivas[:,1].mean()
# Out:
# 30.700617283950617

# %% [markdown]
# __d)__ Calcula el día que ha tenido mayor cantidad de precipitación y la cantidad de precipitación.
#
#    * Utiliza las funciones `argmax` y `max`.

# %%
# Sol: Máxima precipitación: 224.
#      Día de máxima precipitación : 20121222
# print(precip_positivas[:,1].max()) #tambien sirve
maximo = np.argmax(precip_positivas[:,1])
print(precip_positivas[maximo, 1])
precip_positivas.max()
# Out:
# 224
# 20121231

# %% [markdown]
# __e)__ Expresa la cantidad de precipitación en mm. Para ello multiplica la cantidad de precipitación por 10.

# %%
# Sol: Los primeros valores del resultado son:

#    array([[20120101,     2070],
#           [20120102,      -10],
#           [20120103,     1440],
#           [20120104,      360],
#            ...
#            ...
array = precipitaciones[:] * 10
array
# Out:
# array([[201201010,      2070],
#        [201201020,       -10],
#        [201201030,      1440],
#        [201201040,       360],
#        [201201050,       840],
#        [201201060,        80],
#        [201201070,       300],
#        [201201080,       -10],
#        [201201090,        80],
#        [201201100,         0],
#        [201201110,       100],
#        [201201120,        90],
#        [201201130,        40],
#        [201201140,       -10],
#        [201201150,         0],
#        [201201160,         0],
#        [201201170,         0],
#        [201201180,       320],
#        [201201190,      1440],
#        [201201200,       -10],
#        [201201210,       350],
#        [201201220,       190],
#        [201201230,       160],
#        [201201240,        50],
#        [201201250,        50],
#        [201201260,       330],
#        [201201270,       -10],
#        [201201280,       -10],
#        [201201290,         0],
#        [201201300,        10],
#        [201201310,       -10],
#        [201202010,         0],
#        [201202020,         0],
#        [201202030,       270],
#        [201202040,         0],
#        [201202050,         0],
#        [201202060,         0],
#        [201202070,         0],
#        [201202080,         0],
#        [201202090,       -10],
#        [201202100,         0],
#        [201202110,         0],
#        [201202120,        50],
#        [201202130,       180],
#        [201202140,       190],
#        [201202150,       290],
#        [201202160,        60],
#        [201202170,        40],
#        [201202180,       800],
#        [201202190,       250],
#        [201202200,       -10],
#        [201202210,         0],
#        [201202220,       260],
#        [201202230,       -10],
#        [201202240,        10],
#        [201202250,         0],
#        [201202260,         0],
#        [201202270,         0],
#        [201202280,        30],
#        [201202290,       -10],
#        [201203010,         0],
#        [201203020,         0],
#        [201203030,       -10],
#        [201203040,       430],
#        [201203050,       450],
#        [201203060,         0],
#        [201203070,      1230],
#        [201203080,         0],
#        [201203090,         0],
#        [201203100,        10],
#        [201203110,         0],
#        [201203120,         0],
#        [201203130,         0],
#        [201203140,         0],
#        [201203150,         0],
#        [201203160,         0],
#        [201203170,       -10],
#        [201203180,        70],
#        [201203190,         0],
#        [201203200,         0],
#        [201203210,         0],
#        [201203220,         0],
#        [201203230,         0],
#        [201203240,         0],
#        [201203250,         0],
#        [201203260,         0],
#        [201203270,         0],
#        [201203280,         0],
#        [201203290,         0],
#        [201203300,       -10],
#        [201203310,       -10],
#        [201204010,         0],
#        [201204020,         0],
#        [201204030,       -10],
#        [201204040,       400],
#        [201204050,         0],
#        [201204060,       100],
#        [201204070,        30],
#        [201204080,       300],
#        [201204090,       650],
#        [201204100,       230],
#        [201204110,       130],
#        [201204120,       -10],
#        [201204130,       -10],
#        [201204140,         0],
#        [201204150,       -10],
#        [201204160,        60],
#        [201204170,       350],
#        [201204180,        80],
#        [201204190,       320],
#        [201204200,       150],
#        [201204210,       120],
#        [201204220,        10],
#        [201204230,       380],
#        [201204240,       300],
#        [201204250,       250],
#        [201204260,       660],
#        [201204270,        40],
#        [201204280,      1190],
#        [201204290,        10],
#        [201204300,       -10],
#        [201205010,      1020],
#        [201205020,      1130],
#        [201205030,       -10],
#        [201205040,       -10],
#        [201205050,       -10],
#        [201205060,         0],
#        [201205070,        10],
#        [201205080,       660],
#        [201205090,      1240],
#        [201205100,       540],
#        [201205110,       -10],
#        [201205120,        20],
#        [201205130,         0],
#        [201205140,       150],
#        [201205150,      1060],
#        [201205160,       210],
#        [201205170,         0],
#        [201205180,        30],
#        [201205190,         0],
#        [201205200,       510],
#        [201205210,         0],
#        [201205220,         0],
#        [201205230,         0],
#        [201205240,         0],
#        [201205250,         0],
#        [201205260,         0],
#        [201205270,         0],
#        [201205280,         0],
#        [201205290,       350],
#        [201205300,         0],
#        [201205310,       720],
#        [201206010,        50],
#        [201206020,       -10],
#        [201206030,      1010],
#        [201206040,      1570],
#        [201206050,        10],
#        [201206060,       690],
#        [201206070,       170],
#        [201206080,        70],
#        [201206090,       210],
#        [201206100,       -10],
#        [201206110,      1860],
#        [201206120,       160],
#        [201206130,         0],
#        [201206140,         0],
#        [201206150,       960],
#        [201206160,       320],
#        [201206170,       -10],
#        [201206180,      1300],
#        [201206190,         0],
#        [201206200,         0],
#        [201206210,      1120],
#        [201206220,       710],
#        [201206230,         0],
#        [201206240,      1320],
#        [201206250,         0],
#        [201206260,         0],
#        [201206270,         0],
#        [201206280,       -10],
#        [201206290,       -10],
#        [201206300,       370],
#        [201207010,        40],
#        [201207020,         0],
#        [201207030,         0],
#        [201207040,        10],
#        [201207050,       400],
#        [201207060,      1070],
#        [201207070,        60],
#        [201207080,       690],
#        [201207090,       -10],
#        [201207100,        30],
#        [201207110,      1260],
#        [201207120,       670],
#        [201207130,       430],
#        [201207140,       810],
#        [201207150,      1040],
#        [201207160,      2120],
#        [201207170,        10],
#        [201207180,       480],
#        [201207190,       720],
#        [201207200,       -10],
#        [201207210,        10],
#        [201207220,         0],
#        [201207230,         0],
#        [201207240,         0],
#        [201207250,         0],
#        [201207260,         0],
#        [201207270,       830],
#        [201207280,        10],
#        [201207290,       360],
#        [201207300,       970],
#        [201207310,       140],
#        [201208010,       370],
#        [201208020,       510],
#        [201208030,       360],
#        [201208040,        60],
#        [201208050,      1300],
#        [201208060,        80],
#        [201208070,      1180],
#        [201208080,        10],
#        [201208090,         0],
#        [201208100,         0],
#        [201208110,         0],
#        [201208120,         0],
#        [201208130,       200],
#        [201208140,        30],
#        [201208150,        20],
#        [201208160,         0],
#        [201208170,         0],
#        [201208180,         0],
#        [201208190,        60],
#        [201208200,         0],
#        [201208210,       -10],
#        [201208220,         0],
#        [201208230,         0],
#        [201208240,       190],
#        [201208250,       470],
#        [201208260,      1820],
#        [201208270,       -10],
#        [201208280,       240],
#        [201208290,       160],
#        [201208300,       890],
#        [201208310,      1390],
#        [201209010,         0],
#        [201209020,         0],
#        [201209030,       -10],
#        [201209040,         0],
#        [201209050,         0],
#        [201209060,         0],
#        [201209070,         0],
#        [201209080,         0],
#        [201209090,         0],
#        [201209100,        10],
#        [201209110,        40],
#        [201209120,       300],
#        [201209130,         0],
#        [201209140,        80],
#        [201209150,       -10],
#        [201209160,         0],
#        [201209170,        80],
#        [201209180,       500],
#        [201209190,       170],
#        [201209200,       140],
#        [201209210,        50],
#        [201209220,       270],
#        [201209230,       700],
#        [201209240,      1480],
#        [201209250,       780],
#        [201209260,       -10],
#        [201209270,       440],
#        [201209280,        60],
#        [201209290,       100],
#        [201209300,         0],
#        [201210010,       190],
#        [201210020,       120],
#        [201210030,       490],
#        [201210040,      1070],
#        [201210050,      1300],
#        [201210060,      1410],
#        [201210070,         0],
#        [201210080,       -10],
#        [201210090,         0],
#        [201210100,         0],
#        [201210110,        70],
#        [201210120,      1150],
#        [201210130,      1660],
#        [201210140,      1430],
#        [201210150,       140],
#        [201210160,       290],
#        [201210170,       180],
#        [201210180,      1000],
#        [201210190,       350],
#        [201210200,        40],
#        [201210210,        80],
#        [201210220,         0],
#        [201210230,         0],
#        [201210240,        10],
#        [201210250,        30],
#        [201210260,       -10],
#        [201210270,       -10],
#        [201210280,        10],
#        [201210290,      1190],
#        [201210300,      1050],
#        [201210310,       -10],
#        [201211010,       450],
#        [201211020,       160],
#        [201211030,       150],
#        [201211040,      1030],
#        [201211050,       460],
#        [201211060,      1050],
#        [201211070,        40],
#        [201211080,        20],
#        [201211090,        10],
#        [201211100,       420],
#        [201211110,       360],
#        [201211120,        40],
#        [201211130,        50],
#        [201211140,         0],
#        [201211150,         0],
#        [201211160,         0],
#        [201211170,        90],
#        [201211180,       360],
#        [201211190,         0],
#        [201211200,         0],
#        [201211210,        90],
#        [201211220,         0],
#        [201211230,       500],
#        [201211240,       480],
#        [201211250,       170],
#        [201211260,        60],
#        [201211270,        10],
#        [201211280,        90],
#        [201211290,        60],
#        [201211300,       180],
#        [201212010,      1090],
#        [201212020,       930],
#        [201212030,       520],
#        [201212040,       960],
#        [201212050,       290],
#        [201212060,        70],
#        [201212070,      1070],
#        [201212080,        10],
#        [201212090,      1020],
#        [201212100,       160],
#        [201212110,        20],
#        [201212120,       -10],
#        [201212130,       -10],
#        [201212140,      1030],
#        [201212150,        80],
#        [201212160,       240],
#        [201212170,       310],
#        [201212180,       160],
#        [201212190,         0],
#        [201212200,       680],
#        [201212210,        90],
#        [201212220,      2240],
#        [201212230,       760],
#        [201212240,       320],
#        [201212250,      1250],
#        [201212260,       450],
#        [201212270,       270],
#        [201212280,       180],
#        [201212290,        20],
#        [201212300,       230],
#        [201212310,       500]])

# %% [markdown]
# ## Ejercicio 2

# %% [markdown]
# Dos niños están haciendo una colección de cromos. Cada cromo tiene asignado un número entero entre 1 y 200.
#
# * Los cromos que tiene Juan se encuentran en el fichero [juan.txt](./datos/col_juan.txt). La primera columna representa el número asociado al cromo y la segunda columna representa el número de cromos con ese número que tiene Juan.
#
# * Los cromos que tiene Pedro se encuentran en el fichero [pedro.txt](./datos/col_pedro.txt). La primera columna representa el número asociado al cromo y la segunda columna representa el número de cromos con ese número que tiene Pedro.
#
# __a)__ Crear un array de `numpy` con los datos de cada una de las colecciones. Los arrays han de llamarse `juan`y `pedro`.
#
#    * Descarga los ficheros  en tu directorio de trabajo.
#    * Carga cada uno de los ficheros mediante la función `loadtxt`. Usa el parámetro  `delimiter` con valor `,`. Usa el parámetro `dtype` para indicar que los valores sean de tipo `int`.

# %%
# Sol:
juan = np.loadtxt('/content/col_juan.txt', delimiter=',', dtype=int)
pedro = np.loadtxt('/content/col_pedro.txt', delimiter=',', dtype=int)
# Out:
# <ipython-input-9-0fd99e4ad8ea>:2: DeprecationWarning: loadtxt(): Parsing an integer via a float is deprecated.  To avoid this warning, you can:
#     * make sure the original data is stored as integers.
#     * use the `converters=` keyword argument.  If you only use
#       NumPy 1.23 or later, `converters=float` will normally work.
#     * Use `np.loadtxt(...).astype(np.int64)` parsing the file as
#       floating point and then convert it.  (On all NumPy versions.)
#   (Deprecated NumPy 1.23)
#   juan = np.loadtxt('/content/col_juan.txt', delimiter=',', dtype=int)
# <ipython-input-9-0fd99e4ad8ea>:3: DeprecationWarning: loadtxt(): Parsing an integer via a float is deprecated.  To avoid this warning, you can:
#     * make sure the original data is stored as integers.
#     * use the `converters=` keyword argument.  If you only use
#       NumPy 1.23 or later, `converters=float` will normally work.
#     * Use `np.loadtxt(...).astype(np.int64)` parsing the file as
#       floating point and then convert it.  (On all NumPy versions.)
#   (Deprecated NumPy 1.23)
#   pedro = np.loadtxt('/content/col_pedro.txt', delimiter=',', dtype=int)

# %% [markdown]
# __b)__ Calcula el número de cromos diferentes que tiene cada niño.

# %%
# SOl:
# juan tiene 68 cromos
# pedro tiene 124 cromos
print('juan tiene', len(juan), 'cromos')
print('pedro tiene', len(pedro), 'cromos')
# Out:
# juan tiene 68 cromos
# pedro tiene 124 cromos

# %% [markdown]
# __c)__ Calcula el número de cromos totales que tiene cada niño (contando los cromos repetidos).

# %%
# SOl:
# pedro tiene 1326 cromos
# juan tiene 619 cromos
print('pedro tiene', pedro[:,1].sum(), 'cromos')
print('juan tiene', juan[:,1].sum(), 'cromos')
# Out:
# pedro tiene 1326 cromos
# juan tiene 619 cromos

# %% [markdown]
# __d)__ Calcula el número de cromos que aparecen en las dos colecciones. Puedes usar la función `np.intersect1d`.

# %%
# Sol
# Hay 44 cromos que aparecen en las dos colecciones
print('Hay', len(np.intersect1d(juan[:,0], pedro[:,0])), 'cromos que aparecen en las dos colecciones')
# Out:
# Hay 44 cromos que aparecen en las dos colecciones

# %% [markdown]
# __e)__ Entre los dos niños, ¿forman la colección completa?. Puedes usar la función `np.union1d`.

# %%
# Sol:
# No Forman la colección completa. Entre los dos, solo tienen 148 cromos distintos y la colección tiene 200 cromos

coleccion_completa = 200

union_cromos = np.union1d(juan[:,0], pedro[:,0])
num_cromos = len(union_cromos)

if np.array_equal(num_cromos, coleccion_completa):
  print('Forman una colección completa')
else:
  print('No Forman la colección completa. Entre los dos, solo tienen', num_cromos, 'cromos distintos y la colección tiene 200 cromos')
# Out:
# No Forman la colección completa. Entre los dos, solo tienen 148 cromos distintos y la colección tiene 200 cromos

# %% [markdown]
# __f)__ ¿Qué números faltan para tener la colección completa?
#
# * Puedes generar un array de todos los cromos de la colección con la función `arange`.
# * Usa la función `np.in1d`

# %%
# Sol:
# Listado de los cromos que faltan:
#      [  1,   3,  12,  16,  17,  21,  30,  34,  38,  45,  46,  48,  52,
#        55,  66,  69,  72,  75,  76,  81,  82,  91,  92,  96, 100, 106,
#       107, 113, 114, 119, 122, 124, 125, 129, 138, 139, 140, 146, 151,
#       154, 155, 173, 176, 180, 181, 184, 185, 186, 190, 194, 199, 200]

coleccion_completa = np.arange(1, 201)

coleccion_completa[~np.in1d(coleccion_completa, union_cromos)]
# Out:
# array([  1,   3,  12,  16,  17,  21,  30,  34,  38,  45,  46,  48,  52,
#         55,  66,  69,  72,  75,  76,  81,  82,  91,  92,  96, 100, 106,
#        107, 113, 114, 119, 122, 124, 125, 129, 138, 139, 140, 146, 151,
#        154, 155, 173, 176, 180, 181, 184, 185, 186, 190, 194, 199, 200])

# %% [markdown]
# ---------------------
