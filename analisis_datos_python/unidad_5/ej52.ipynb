# %% [markdown]
# <div id="navegacion" prev="../Tema_7/t7_pandas_034.html" next=""></div>
#
# <div class="section-title">Sección 5.5</div>

# %% [markdown]
# # Ejercicios

# %% [markdown]
# ## Ejercicio 1

# %% [markdown]
# El fichero [pedidos.csv](./datos/pedidos.csv) recoge los datos de los pedidos de una empresa en su último trimestre. Cada pedido puede tener distintas lineas de pedido, donde cada línea representa un producto.
#
# La información del fichero por columnas es:
# * Número de pedido
# * Linea de pedido
# * Producto
# * Cantidad
# * Precio unitario en Euros (separador de decimales = ',')
#
#
#
# __a)__ Carga los datos en un DataFrame con la función `read_csv`.
#
# * El índice del DataFrame ha de ser el número de pedido.
# * Para ver las opcciones de la función `read_csv` ejecuta la siguiente celda:

# %%
import pandas as pd
pd.read_excel?

# %%
# Sol:
excel = pd.read_csv('/content/pedidos.csv', delimiter='|', decimal=',', index_col="Numero_pedido")
excel.head()
# Out:
#                 producto  cantidad  precio  linea_de_pedido
# Numero_pedido
# 10105          S700_2610        31   65.77                3
# 10105          S700_3505        39   81.14                6
# 10105          S700_3962        22  116.19                7
# 10105           S72_3212        25   56.78                8
# 10106           S18_1662        36  146.65               12

# %% [markdown]
# __b)__ Modifica los valores del precio unitario a 0 cuando el valor sea NaN.

# %%
# Sol:
excel.fillna({'precio':0})
excel
# Out:
#                 producto  cantidad  precio  linea_de_pedido
# Numero_pedido
# 10105          S700_2610        31   65.77                3
# 10105          S700_3505        39   81.14                6
# 10105          S700_3962        22  116.19                7
# 10105           S72_3212        25   56.78                8
# 10106           S18_1662        36  146.65               12
# ...                  ...       ...     ...              ...
# 10126          S700_2824        45  102.16                6
# 10127           S12_1108        46  245.20                2
# 10127           S12_3148        46  160.14                3
# 10127           S12_3891        42  193.78                1
# 10127           S12_4473        24  106.65               11
#
# [200 rows x 4 columns]

# %% [markdown]
# __c)__ Calcula el número de pedido (o pedidos) que contengan el producto más caro.

# %%
# Sol:
max_precio = excel['precio'].max()
num_pedidos = excel[excel['precio'] == max_precio]
num_pedidos
# Out:
#                producto  cantidad  precio  linea_de_pedido
# Numero_pedido
# 10112          S10_1949        29  248.59                1

# %% [markdown]
# __d)__ ¿Qué productos aparecen en los pedidos del dataset? Usa `unique`.

# %%
# Sol:
print(excel['producto'].unique())
# Out:
# ['S700_2610' 'S700_3505' 'S700_3962' 'S72_3212' 'S18_1662' 'S18_2581'
#  'S18_3029' 'S18_3856' 'S24_1785' 'S24_2841' 'S24_3420' 'S24_3949'
#  'S24_4278' 'S32_4289' 'S50_1341' 'S700_1691' 'S700_2047' 'S700_2466'
#  'S700_2834' 'S700_3167' 'S700_4002' 'S72_1253' 'S10_1678' 'S10_2016'
#  'S10_4698' 'S12_2823' 'S18_2625' 'S24_1578' 'S24_2000' 'S32_1374'
#  'S12_1099' 'S12_3380' 'S12_3990' 'S12_4675' 'S18_1889' 'S18_3278'
#  'S18_3482' 'S18_3782' 'S18_4721' 'S24_2360' 'S24_3371' 'S24_3856'
#  'S24_4620' 'S32_2206' 'S32_4485' 'S50_4713' 'S18_1129' 'S18_1984'
#  'S18_2870' 'S18_3232' 'S18_3685' 'S24_2972' 'S18_1589' 'S18_1749'
#  'S18_2248' 'S18_2325' 'S18_2795' 'S18_4409' 'S18_4933' 'S24_1046'
#  'S24_1628' 'S24_1937' 'S24_2022' 'S24_2766' 'S24_2887' 'S24_3191'
#  'S24_3432' 'S24_3969' 'S18_1342' 'S18_1367' 'S18_2957' 'S18_3136'
#  'S18_3320' 'S24_4258' 'S10_1949' 'S18_2949' 'S12_1666' 'S18_1097'
#  'S18_4668' 'S32_3522' 'S10_4962' 'S18_2319' 'S18_2432' 'S18_4600'
#  'S24_2300' 'S24_2840' 'S32_1268' 'S32_2509' 'S700_2824' 'S12_4473'
#  'S18_2238' 'S24_1444' 'S24_4048' 'S50_1392' 'S32_3207' 'S12_1108'
#  'S12_3148' 'S12_3891' 'S18_3140' 'S18_3259' 'S18_4027' 'S18_4522'
#  'S24_2011' 'S50_1514' 'S700_1938' 'S10_4757' 'S24_3151' 'S24_3816'
#  'S700_1138']

# %% [markdown]
# __e)__ ¿Cúantas veces aparece cada producto en el dataset? Usa `value_counts`.

# %%
# Sol:
print(excel['producto'].value_counts())
# Out:
# producto
# S18_3232     3
# S700_2610    2
# S18_4933     2
# S24_3432     2
# S24_3191     2
#             ..
# S24_1444     1
# S18_2238     1
# S32_2509     1
# S24_2840     1
# S700_1138    1
# Name: count, Length: 109, dtype: int64

# %% [markdown]
# __f)__ Crea una nueva columna llamada `total_linea` que sea el importe total de la línea de pedido (precio unitario multiplicado por la cantidad).

# %%
# Sol:
excel['total_linea'] = excel['cantidad'] * excel['precio']
excel
# Out:
#                 producto  cantidad  precio  linea_de_pedido  total_linea
# Numero_pedido
# 10105          S700_2610        31   65.77                3      2038.87
# 10105          S700_3505        39   81.14                6      3164.46
# 10105          S700_3962        22  116.19                7      2556.18
# 10105           S72_3212        25   56.78                8      1419.50
# 10106           S18_1662        36  146.65               12      5279.40
# ...                  ...       ...     ...              ...          ...
# 10126          S700_2824        45  102.16                6      4597.20
# 10127           S12_1108        46  245.20                2     11279.20
# 10127           S12_3148        46  160.14                3      7366.44
# 10127           S12_3891        42  193.78                1      8138.76
# 10127           S12_4473        24  106.65               11      2559.60
#
# [200 rows x 5 columns]

# %% [markdown]
# __g)__ Incrementa el precio de las líneas de pedido un 10% para aquellos productos cuyo precio sea superior a 80 Euros. Para ello crea una nueva columna llamada `Descuento`.
#
# * Crea una función que reciba como parámetro un valor de tipo entero que representa el precio. Si dicho valor es mayor de 80, la función lo devuelve incrementado en un 10%. Si el valor es menor o igual a 80, la función devuelve dicho valor sin cambios.
# * Aplica la función anterior usando  `map` sobre la columna `precio`.

# %%
# Sol:
def descuento(precio):
  if precio > 80:
    precio = precio * 1.10
  return precio

excel['Descuento'] = excel['precio'].map(descuento)
excel
# Out:
#                 producto  cantidad  precio  linea_de_pedido  total_linea  \
# Numero_pedido
# 10105          S700_2610        31   65.77                3      2038.87
# 10105          S700_3505        39   81.14                6      3164.46
# 10105          S700_3962        22  116.19                7      2556.18
# 10105           S72_3212        25   56.78                8      1419.50
# 10106           S18_1662        36  146.65               12      5279.40
# ...                  ...       ...     ...              ...          ...
# 10126          S700_2824        45  102.16                6      4597.20
# 10127           S12_1108        46  245.20                2     11279.20
# 10127           S12_3148        46  160.14                3      7366.44
# 10127           S12_3891        42  193.78                1      8138.76
# 10127           S12_4473        24  106.65               11      2559.60
#
#                Descuento
# Numero_pedido
# 10105             65.770
# 10105             89.254
# 10105            127.809
# 10105             56.780
# 10106            161.315
# ...                  ...
# 10126            112.376
# 10127            269.720
# 10127            176.154
# 10127            213.158
# 10127            117.315
#
# [200 rows x 6 columns]
